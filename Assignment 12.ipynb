# %%
#1
from scipy.stats import binom
import matplotlib.pyplot as plt

n = 20
p= 0.12452

r_values = list(range(n + 1))

dist = [binom.pmf(r, n, p) for r in r_values ]


plt.bar(r_values, dist)
plt.xlabel("Weather")
plt.ylabel("Binomal")
plt.title("Rainy Days")
plt.show()

# %%
#2
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

m = ()
sd = 2
x=np.arange(10,30,0.1)
y=norm.pdf(x, x.mean(), sd)
plt.plot(x,y)
plt.show()

# %%
#3
import pandas as pd
df = pd.read_csv("bm_results2012.csv")
a = df['official'].sample(n=100, random_state=1)
a.plot.hist(grid=True, bins=20, rwidth=0.9,color='#607c8e')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16548/889837141.py in <module>
#       1 #3
#       2 import pandas as pd
# ----> 3 df = pd.read_csv("bm_results2012.csv")
#       4 a = df['official'].sample(n=100, random_state=1)
#       5 a.plot.hist(grid=True, bins=20, rwidth=0.9,color='#607c8e')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#4
#MALE
df_male = df[df['gender'] == 'M']
male_samples = df_male['official'].sample(n=100, random_state=1)
male_samples.plot.hist(grid=True, bins=20, rwidth=0.9,color='#607c8e')
import numpy as np


n, bins = np.histogram(male_samples)
mids = 0.5*(bins[1:] + bins[:-1])
mean = np.average(mids, weights=n)
var = np.average((mids - mean)**2, weights=n)
np.sqrt(var)
df_male_samples = male_samples.to_frame()
df_male_samples
df_male_samples.sem(axis =0)

alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower =  np.percentile(mean, p)
p = (alpha+((1.0-alpha)/2.0)) * 100
upper =  np.percentile(mean, p)

#-------------------------------------------------------------------------------
#FEMALE
df_male = df[df['gender'] == 'F']
female_samples = df_female['official'].sample(n=100, random_state=1)
female_samples.plot.hist(grid=True, bins=20, rwidth=0.9,color='#607c8e')
import numpy as np
n, bins = np.histogram(female_samples)
mids = 0.5*(bins[1:] + bins[:-1])
mean = np.average(mids, weights=n)
var = np.average((mids - mean)**2, weights=n)
np.sqrt(var)
df_female_samples = female_samples.to_frame()
df_female_samples
df_female_samples.sem(axis =0)

# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower =  np.percentile(mean, p)
p = (alpha+((1.0-alpha)/2.0)) * 100
upper =  np.percentile(mean, p)
